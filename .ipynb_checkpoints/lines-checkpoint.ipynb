# %%
from scipy import ndimage
import numpy as np
import cv2
import matplotlib.pyplot as plt
from collections import defaultdict
from sklearn.cluster import DBSCAN

# %%
def cv_rgb2gray(rgb):
    gray = np.mean(rgb, axis=2)
    return gray

def cv_binarization(gray_img, threshold = 100):
    binarized = 1.0 * (gray_img > threshold)
    return binarized

def cv_opening(img, kernel, iter_erosion= 1, iter_dilatation = 1):
    img = cv2.erode(img, kernel, iter_erosion)
    img = cv2.dilate(img, kernel, iter_dilatation)
    return img

def cv_closing(img, kernel, iter_erosion= 1, iter_dilatation = 1):
    img = cv2.dilate(img, kernel, iter_dilatation)
    img = cv2.erode(img, kernel, iter_erosion)
    return img

def kernel_square(n):
    kernel  = np.ones((n, n),np.uint8)
    return kernel

def kernel_unique(n, m):
    kernel  = np.ones((n, m),np.uint8)
    return kernel

# %%
def view(img):
    plt.figure(figsize=(10, 10))
    plt.imshow(img, cmap='gray')

# %%
img = cv2.imread("./DATA/1.jpg")
img = img[500: 850, 100:375]
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img2 = img.copy()

# %%
view(img)

# %%
blur = cv2.blur(gray, (3, 3))

# %%
view(blur)

# %%
ret, otsu = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# %%
otsu = 255 - otsu

# %%
view(otsu)

# %%
f1 = cv_opening(otsu, kernel=kernel_unique(1, 25))
view(f1)

# %%
rho, theta, thresh = 2, np.pi/180, 150
lines_h = cv2.HoughLines(f1, rho, theta, thresh)
new_lines_h = []

# %%
for line in lines_h:
    # rho Это дистанция до кординаты (center,center)
    # theta угол повората изображения
    rho, theta = line[0]
    # a нормирование 
    # b нормирование
    a = np.cos(theta)
    b = np.sin(theta)
    if b > 0.99 and a < 0.02:
        # кадинаты
        x0 = a * rho
        y0 = b * rho
        # начало вектора
        x1 = int(x0 + 1000 * (-b))
        y1 = int(y0 + 1000 * (a))
        # конец вектора
        x2 = int(x0 - 1000 * (-b))
        y2 = int(y0 - 1000 * (a))
        # Рисование 
        cv2.line(img, (x1, y1), (x2, y2), (0, 255, 255), 2)
        new_lines_h.append(line)

# %%
f2 = cv_opening(otsu, kernel=kernel_unique(11, 1))
view(f2)

# %%
rho, theta, thresh = 2, np.pi/180, 171
lines_v = cv2.HoughLines(f2, rho, theta, thresh)
new_lines_v = []

# %%
for line in lines_v:
    # rho Это дистанция до кординаты (center,center)
    # theta угол повората изображения
    rho, theta = line[0]
    # a нормирование 
    # b нормирование
    a = np.cos(theta)
    b = np.sin(theta)
    if a > 0.99 and b < 0.02:
        # кадинаты
        x0 = a * rho
        y0 = b * rho
        # начало вектора
        x1 = int(x0 + 1000 * (-b))
        y1 = int(y0 + 1000 * (a))
        # конец вектора
        x2 = int(x0 - 1000 * (-b))
        y2 = int(y0 - 1000 * (a))
        # Рисование 
        cv2.line(img, (x1, y1), (x2, y2), (0, 255, 255), 2)
        new_lines_v.append(line)

# %%
new_img = img.copy()

# %%
lines = np.concatenate((new_lines_h, new_lines_v), axis=0)

# %%
clustering_lines_h = []
clustering_lines_v = []

for line in new_lines_h:
    clustering_lines_h.append(line[0])
    
for line in new_lines_v:
    clustering_lines_v.append(line[0])

# %%
clustering = DBSCAN(eps=7, min_samples=1).fit(clustering_lines_h)
print(len(np.unique(clustering.labels_)))

clustering_lines_h = np.array(clustering_lines_h)
clustering_lines_h = np.insert(clustering_lines_h, 2, clustering.labels_, axis=1)

number_of_clusters = np.unique(clustering.labels_)
print(number_of_clusters)

h_lines= []
for cluster in number_of_clusters:
    cluseter_indexs = np.where(clustering_lines_h[:, 2].astype(int) == int(cluster))[0]
    buffer = []
    for index in cluseter_indexs:
        buffer.append(clustering_lines_h[index, :2])
    mean = np.array(buffer).mean(axis=0)
    h_lines.append(mean)
    
h_lines
# Out:
# 6
# [0 1 2 3 4 5]
# [array([257.       ,   1.5707964], dtype=float32),
#  array([203.      ,   1.576614], dtype=float32),
#  array([95.       ,  1.5707964], dtype=float32),
#  array([148.       ,   1.5620697], dtype=float32),
#  array([312.33334  ,   1.5707964], dtype=float32),
#  array([39.       ,  1.5882496], dtype=float32)]

# %%
clustering = DBSCAN(eps=5, min_samples=1).fit(clustering_lines_v)
print(len(np.unique(clustering.labels_)))

clustering_lines_v = np.array(clustering_lines_v)
clustering_lines_v = np.insert(clustering_lines_v, 2, clustering.labels_, axis=1)

number_of_clusters = np.unique(clustering.labels_)
print(number_of_clusters)

v_lines= []
for cluster in number_of_clusters:
    cluseter_indexs = np.where(clustering_lines_v[:, 2].astype(int) == int(cluster))[0]
    buffer = []
    for index in cluseter_indexs:
        buffer.append(clustering_lines_v[index, :2])
    mean = np.array(buffer).mean(axis=0)
    v_lines.append(mean)
    
h_lines
# Out:
# 5
# [0 1 2 3 4]
# [array([257.       ,   1.5707964], dtype=float32),
#  array([203.      ,   1.576614], dtype=float32),
#  array([95.       ,  1.5707964], dtype=float32),
#  array([148.       ,   1.5620697], dtype=float32),
#  array([312.33334  ,   1.5707964], dtype=float32),
#  array([39.       ,  1.5882496], dtype=float32)]

# %%
lines2 = np.concatenate((h_lines, v_lines), axis=0)

# %%
lines2 = lines2.reshape(11, 1, 2)

# %%
def intersection(line1, line2):
    """Finds the intersection of two lines given in Hesse normal form.

    Returns closest integer pixel locations.
    See https://stackoverflow.com/a/383527/5087436
    """
    rho1, theta1 = line1
    rho2, theta2 = line2
    A = np.array([
        [np.cos(theta1), np.sin(theta1)],
        [np.cos(theta2), np.sin(theta2)]
    ])
    b = np.array([[rho1], [rho2]])
    x0, y0 = np.linalg.lstsq(A, b)[0]
    x0, y0 = int(np.round(x0)), int(np.round(y0))
    return [[x0, y0]]

# %%
def segmented_intersections(lines):
    """Finds the intersections between groups of lines."""

    intersections = []
    for i, group in enumerate(lines[:-1]):
        for next_group in lines[i+1:]:
            for line1 in group:
                for line2 in next_group:
                    intersections.append(intersection(line1, line2)) 

    return intersections

# %%
intersections = segmented_intersections(lines2)
# Out:
# c:\users\nafe9\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
for line in lines2:
    # rho Это дистанция до кординаты (center,center)
    # theta угол повората изображения
    rho, theta = line[0]
    # a нормирование 
    # b нормирование
    a = np.cos(theta)
    b = np.sin(theta)
    
    # кадинаты
    x0 = a * rho
    y0 = b * rho
    # начало вектора
    x1 = int(x0 + 1000 * (-b))
    y1 = int(y0 + 1000 * (a))
    # конец вектора
    x2 = int(x0 - 1000 * (-b))
    y2 = int(y0 - 1000 * (a))
    # Рисование 
    cv2.line(img2, (x1, y1), (x2, y2), (0, 255, 255), 2)

# %%
for intersection in intersections:
    center_coordinates_x = intersection[0][0]
    center_coordinates_y = intersection[0][1]
    # Radius of circle
    radius = 1
    # Red color in BGR
    color = (0, 0, 255)
    # Line thickness of -1 px
    thickness = -1
    
    image = cv2.circle(img2, (center_coordinates_x, center_coordinates_y), radius, color, thickness)

# %%
view(img2)
